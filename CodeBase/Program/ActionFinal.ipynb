# %%
from __future__ import print_function
import sys
import os
import csv
import numpy as np
from random import randint

from PIL import Image
import imageio

import cntk as C
from cntk.logging import *
from cntk.debugging import set_computation_network_trace_level

# %%
# Paths relative to current python file.
#abs_path   = os.path.dirname(os.path.abspath(__file__))
data_path  = os.path.join(os.getcwd(), "..", "..", "DataSets", "UCF11")
model_path = os.path.join(os.getcwd(), "Models")

# %%
# Define the reader for both training and evaluation action.
class VideoReader(object):

    def __init__(self, map_file, label_count, is_training, limit_epoch_size=sys.maxsize):
        
        self.map_file        = map_file
        self.label_count     = label_count
        self.width           = 112
        self.height          = 112
        self.sequence_length = 16
        self.channel_count   = 3
        self.is_training     = is_training
        self.video_files     = []
        self.targets         = []
        self.batch_start     = 0

        map_file_dir = os.path.dirname(map_file)

        with open(map_file) as csv_file:
            data = csv.reader(csv_file)
            for row in data:
                print("CSV load: reading row",row)
                self.video_files.append(os.path.join(map_file_dir, row[0]))
                target = [0.0] * self.label_count
                target[int(row[1])] = 1.0
                self.targets.append(target)

        self.indices = np.arange(len(self.video_files))
        if self.is_training:
            np.random.shuffle(self.indices)
        self.epoch_size = min(len(self.video_files), limit_epoch_size)
    def size(self):
        return self.epoch_size
            
    def has_more(self):
        if self.batch_start < self.size():
            return True
        return False

    def reset(self):
        if self.is_training:
            np.random.shuffle(self.indices)
        self.batch_start = 0

    def next_minibatch(self, batch_size):
        '''
        Return a mini batch of sequence frames and their corresponding ground truth.
        '''
        batch_end = min(self.batch_start + batch_size, self.size())
        current_batch_size = batch_end - self.batch_start
        if current_batch_size < 0:
            raise Exception('Reach the end of the training data.')

        inputs  = np.empty(shape=(current_batch_size, self.channel_count, self.sequence_length, self.height, self.width), dtype=np.float32)
        targets = np.empty(shape=(current_batch_size, self.label_count), dtype=np.float32)
        for idx in range(self.batch_start, batch_end):
            index = self.indices[idx]
            inputs[idx - self.batch_start, :, :, :, :] = self._select_features(self.video_files[index])
            targets[idx - self.batch_start, :]         = self.targets[index]

        self.batch_start += current_batch_size
        return inputs, targets, current_batch_size

    def _select_features(self, video_file):
        '''
        Select a sequence of frames from video_file and return them as
        a Tensor.
        '''
        video_reader = imageio.get_reader(video_file, 'ffmpeg')
        num_frames   = len(video_reader)
        if self.sequence_length > num_frames:
            raise ValueError('Sequence length {} is larger then the total number of frames {} in {}.'.format(self.sequence_length, num_frames, video_file))

        # select which sequence frames to use.
        step = 1
        expanded_sequence = self.sequence_length
        if num_frames > 2*self.sequence_length:
            step = 2
            expanded_sequence = 2*self.sequence_length

        seq_start = int(num_frames/2) - int(expanded_sequence/2)
        if self.is_training:
            seq_start = randint(0, num_frames - expanded_sequence)

        frame_range = [seq_start + step*i for i in range(self.sequence_length)]            
        video_frames = []
        for frame_index in frame_range:
            video_frames.append(self._read_frame(video_reader.get_data(frame_index)))
        
        return np.stack(video_frames, axis=1)

    def _read_frame(self, data):
        
        if (self.width >= 171) or (self.height >= 128):
            raise ValueError("Target width need to be less than 171 and target height need to be less than 128.")
        
        image = Image.fromarray(data)
        image.thumbnail((171, 128), Image.ANTIALIAS)
        
        center_w = image.size[0] / 2
        center_h = image.size[1] / 2

        image = image.crop((center_w - self.width  / 2,
                            center_h - self.height / 2,
                            center_w + self.width  / 2,
                            center_h + self.height / 2))
        
        norm_image = np.array(image, dtype=np.float32)
        norm_image -= 127.5
        norm_image /= 127.5

        # (channel, height, width)
        return np.ascontiguousarray(np.transpose(norm_image, (2, 0, 1)))

# %%
def conv3d_ucf3(train_reader, test_reader, max_epochs=1):
    # Replace 0 with 1 to get detailed log.
    set_computation_network_trace_level(1)

    # These values must match for both train and test reader.
    image_height       = train_reader.height
    image_width        = train_reader.width
    num_channels       = train_reader.channel_count
    sequence_length    = train_reader.sequence_length
    num_output_classes = train_reader.label_count

    # Input variables denoting the features and label data
    input_var = C.input_variable((num_channels, sequence_length, image_height, image_width), np.float32)
    label_var = C.input_variable(num_output_classes, np.float32)


    with C.default_options (activation=C.relu):
        z = C.layers.Sequential([
            C.layers.Convolution3D((3,3,3), 64, pad=True),
            C.layers.MaxPooling((1,2,2), (1,2,2)),
            C.layers.For(range(3), lambda i: [
                C.layers.Convolution3D((3,3,3), [96, 128, 128][i], pad=True),
                C.layers.Convolution3D((3,3,3), [96, 128, 128][i], pad=True),
                C.layers.MaxPooling((2,2,2), (2,2,2))
            ]),
            C.layers.For(range(2), lambda : [
                C.layers.Dense(1024), 
                C.layers.Dropout(0.5)
            ]),
            C.layers.Dense(num_output_classes, activation=None)
        ])(input_var)
    
    # loss and classification error.
    ce = C.cross_entropy_with_softmax(z, label_var)
    pe = C.classification_error(z, label_var)

    # training config
    train_epoch_size     = train_reader.size()
    train_minibatch_size = 2

    # Set learning parameters
    lr_per_sample          = [0.01]*10+[0.001]*10+[0.0001]
    lr_schedule            = C.learning_parameter_schedule_per_sample(lr_per_sample, epoch_size=train_epoch_size)
    momentum_per_sample = 0.9997558891748972
    mm_schedule            = C.momentum_schedule_per_sample([momentum_per_sample])

    # Instantiate the trainer object to drive the model training
    learner = C.momentum_sgd(z.parameters, lr_schedule, mm_schedule, True)
    progress_printer = ProgressPrinter(tag='Training', num_epochs=max_epochs)
    trainer = C.Trainer(z, (ce, pe), learner, progress_printer)

    log_number_of_parameters(z) ; print()

    # Get minibatches of images to train with and perform model training
    for epoch in range(max_epochs):       # loop over epochs
        train_reader.reset()
        mbcount = 0
        while train_reader.has_more():
            print("Train Minibatch : ", mbcount)
            videos, labels, current_minibatch = train_reader.next_minibatch(train_minibatch_size)
            trainer.train_minibatch({input_var : videos, label_var : labels})
            mbcount += 1

        trainer.summarize_training_progress()

    # Test data for trained model
    epoch_size     = test_reader.size()
    test_minibatch_size = 2

    # process minibatches and evaluate the model
    metric_numer    = 0
    metric_denom    = 0
    minibatch_index = 0

    test_reader.reset()    
    while test_reader.has_more():
        print("test minibatch: ", minibatch_index)
        videos, labels, current_minibatch = test_reader.next_minibatch(test_minibatch_size)
        # minibatch data to be trained with
        metric_numer += trainer.test_minibatch({input_var : videos, label_var : labels}) * current_minibatch
        metric_denom += current_minibatch
        # Keep track of the number of samples processed so far.
        minibatch_index += 1

    print("")
    print("Final Results: Minibatch[1-{}]: errs = {:0.2f}% * {}".format(minibatch_index+1, (metric_numer*100.0)/metric_denom, metric_denom))
    print("")
    acc = 100 - metric_numer
    print("Accuracy : ", acc)

    return metric_numer/metric_denom

# %%
if __name__=='__main__':
    num_output_classes = 3
    train_reader = VideoReader(os.path.join(data_path, 'train_map.csv'), num_output_classes, True)
    test_reader  = VideoReader(os.path.join(data_path, 'test_map.csv'), num_output_classes, False)
        
    conv3d_ucf3(train_reader, test_reader)
# Out:
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_03\\v_jumping_03_01.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_03\\v_jumping_03_02.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_03\\v_jumping_03_03.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_03\\v_jumping_03_04.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_08\\v_jumping_08_01.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_08\\v_jumping_08_02.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_08\\v_jumping_08_03.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_08\\v_jumping_08_04.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_23\\v_biking_23_01.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_23\\v_biking_23_02.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_23\\v_biking_23_03.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_23\\v_biking_23_04.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_25\\v_jumping_25_01.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_25\\v_jumping_25_02.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_25\\v_jumping_25_03.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_25\\v_jumping_25_04.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_04\\v_golf_04_01.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_04\\v_golf_04_02.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_04\\v_golf_04_03.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_04\\v_golf_04_04.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_04\\v_golf_04_05.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_04\\v_golf_04_06.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_02\\v_golf_02_01.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_02\\v_golf_02_02.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_02\\v_golf_02_03.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_02\\v_golf_02_04.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_17\\v_jumping_17_01.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_17\\v_jumping_17_02.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_17\\v_jumping_17_03.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_17\\v_jumping_17_04.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_05\\v_jumping_05_01.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_05\\v_jumping_05_02.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_05\\v_jumping_05_03.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_05\\v_jumping_05_04.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_10\\v_golf_10_01.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_10\\v_golf_10_02.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_10\\v_golf_10_03.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_10\\v_golf_10_04.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_08\\v_biking_08_01.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_08\\v_biking_08_02.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_08\\v_biking_08_03.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_08\\v_biking_08_04.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_08\\v_biking_08_05.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_08\\v_biking_08_06.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_19\\v_golf_19_01.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_19\\v_golf_19_02.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_19\\v_golf_19_03.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_19\\v_golf_19_04.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_19\\v_golf_19_05.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_19\\v_golf_19_06.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_10\\v_jumping_10_01.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_10\\v_jumping_10_02.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_10\\v_jumping_10_03.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_10\\v_jumping_10_04.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_10\\v_jumping_10_05.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_10\\v_jumping_10_06.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_17\\v_golf_17_01.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_17\\v_golf_17_02.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_17\\v_golf_17_03.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_17\\v_golf_17_04.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_17\\v_golf_17_05.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_17\\v_golf_17_06.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_17\\v_golf_17_07.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_17\\v_golf_17_08.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_16\\v_golf_16_01.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_16\\v_golf_16_02.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_16\\v_golf_16_03.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_16\\v_golf_16_04.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_09\\v_golf_09_01.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_09\\v_golf_09_02.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf
01.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_13\\v_biking_13_02.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_13\\v_biking_13_03.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_13\\v_biking_13_04.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_13\\v_biking_13_05.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_13\\v_biking_13_06.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_12\\v_golf_12_01.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_12\\v_golf_12_02.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_12\\v_golf_12_03.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_12\\v_golf_12_04.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_22\\v_biking_22_01.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_22\\v_biking_22_02.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_22\\v_biking_22_03.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_22\\v_biking_22_04.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_22\\v_biking_22_05.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_10\\v_biking_10_01.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_10\\v_biking_10_02.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_10\\v_biking_10_03.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_10\\v_biking_10_04.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_10\\v_biking_10_05.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\biking\\v_biking_10\\v_biking_10_06.avi', '0']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_22\\v_jumping_22_01.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_22\\v_jumping_22_02.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_22\\v_jumping_22_03.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_22\\v_jumping_22_04.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_22\\v_jumping_22_05.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_22\\v_jumping_22_06.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_18\\v_jumping_18_01.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_18\\v_jumping_18_02.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_18\\v_jumping_18_03.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_18\\v_jumping_18_04.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_15\\v_jumping_15_01.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_15\\v_jumping_15_02.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_15\\v_jumping_15_03.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_15\\v_jumping_15_04.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\trampoline_jumping\\v_jumping_15\\v_jumping_15_05.avi', '2']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_23\\v_golf_23_01.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_23\\v_golf_23_02.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_23\\v_golf_23_03.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_23\\v_golf_23_04.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_23\\v_golf_23_05.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_23\\v_golf_23_06.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_23\\v_golf_23_07.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_23\\v_golf_23_08.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_20\\v_golf_20_01.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_20\\v_golf_20_02.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_20\\v_golf_20_03.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_20\\v_golf_20_04.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_20\\v_golf_20_05.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_20\\v_golf_20_06.avi', '1']
# CSV load: reading row ['C:\\Users\\AbhishekGangadhar\\Downloads\\ActionRecog\\ActionRecog\\DataSets\\UCF11\\action_youtube_naudio\\golf_swing\\v_golf_20\\v_golf_20_07.avi', '1']
# Training 15978307 parameters in 20 parameter tensors.
#
# Train Minibatch :  0
# Learning rate per 1 samples: 0.01
# Momentum per 1 samples: 0.9997558891748972
# Train Minibatch :  1
# Train Minibatch :  2
# Train Minibatch :  3
# Train Minibatch :  4
# Train Minibatch :  5
# Train Minibatch :  6
# Train Minibatch :  7
# Train Minibatch :  8
# Train Minibatch :  9
# Train Minibatch :  10
# Train Minibatch :  11
# Train Minibatch :  12
# Train Minibatch :  13
# Train Minibatch :  14
# Train Minibatch :  15
# Train Minibatch :  16
# Train Minibatch :  17
# Train Minibatch :  18
# Train Minibatch :  19
# Train Minibatch :  20
# Train Minibatch :  21
# Train Minibatch :  22
# Train Minibatch :  23
# Train Minibatch :  24
# Train Minibatch :  25
# Train Minibatch :  26
# Train Minibatch :  27
# Train Minibatch :  28
# Train Minibatch :  29
# Train Minibatch :  30
# Train Minibatch :  31
# Train Minibatch :  32
# Train Minibatch :  33
# Train Minibatch :  34
# Train Minibatch :  35
# Train Minibatch :  36
# Train Minibatch :  37
# Train Minibatch :  38
# Train Minibatch :  39
# Train Minibatch :  40
# Train Minibatch :  41
# Train Minibatch :  42
# Train Minibatch :  43
# Train Minibatch :  44
# Train Minibatch :  45
